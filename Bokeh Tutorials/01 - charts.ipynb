# %% [markdown]
# <a href="http://bokeh.pydata.org/"><img src="assets/images/bokeh-transparent.png" style="width:70px; float: left;"></a><h1>Bokeh Tutorial &mdash; <code>bokeh.charts</code> interface</h1>
#
# ---
#
# The `charts` interface was completely re-written for `0.10`. Not all chart types have been ported over into the new format, and a `_legacy_charts` module remains for previous charts you might have used. Today we will only be demonstrating the new charts interface.

# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e6b241a6-b3ae-4321-8acf-3f439fb636ac">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Chart inputs
#
# Supported inputs for charts are:
# * Array-like - list, tuple, numpy.ndarray, pandas.Series
# * Table-like - records: list(dict), columns: dict(list), pandas.DataFrame, blaze resource
#
# Today, we're just going to work with pandas DataFrames, but all these examples should work with any appropriate data input.

# %%
from bokeh.sampledata.iris import flowers
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # Scatter plot

# %%
from bokeh.charts import Scatter

p = Scatter(flowers, x='petal_length', y='petal_width', color='species', legend='top_left')
show(p)
# Out:
#     <div class="plotdiv" id="a68cdfdd-f810-459c-b578-7ced5c391f8e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a68cdfdd-f810-459c-b578-7ced5c391f8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a68cdfdd-f810-459c-b578-7ced5c391f8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7bceab78-5f3e-4a99-887b-e19c8dfec9ab":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"}],"species":["versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor"],"x_values":[4.7,4.5,4.9,4.0,4.6,4.5,4.7,3.3,4.6,3.9,3.5,4.2,4.0,4.7,3.6,4.4,4.5,4.1,4.5,3.9,4.8,4.0,4.9,4.7,4.3,4.4,4.8,5.0,4.5,3.5,3.8,3.7,3.9,5.1,4.5,4.5,4.7,4.4,4.1,4.0,4.4,4.6,4.0,3.3,4.2,4.2,4.2,4.3,3.0,4.1],"y_values":[1.4,1.5,1.5,1.3,1.5,1.3,1.6,1.0,1.3,1.4,1.0,1.5,1.0,1.4,1.3,1.4,1.5,1.0,1.5,1.1,1.8,1.3,1.5,1.2,1.3,1.4,1.4,1.7,1.5,1.0,1.1,1.0,1.2,1.6,1.5,1.6,1.5,1.3,1.3,1.3,1.2,1.4,1.2,1.0,1.3,1.2,1.3,1.3,1.1,1.3]}},"id":"1b45ee61-a60c-4f32-9965-13ee51a0b274","type":"ColumnDataSource"},{"attributes":{"axis_label":"petal_length","formatter":{"id":"9147b18e-7c2f-46a7-8d85-04e0ec2abfdb","type":"BasicTickFormatter"},"plot":{"id":"56eee1cb-e185-4e3d-bfe9-5b78f0f0bc52","subtype":"Chart","type":"Plot"},"ticker":{"id":"745babd9-ae7c-4895-b5af-03af69ae9067","type":"BasicTicker"}},"id":"bd798134-f64d-4b00-9dc8-f3bdb40abc77","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"a603b0b3-6fe0-4ce4-9c95-f03c68f1136e","type":"Circle"},{"attributes":{"axis_label":"petal_width","formatter":{"id":"edffe9f8-f5ab-4562-bc29-e6dfe2032bd3","type":"BasicTickFormatter"},"plot":{"id":"56eee1cb-e185-4e3d-bfe9-5b78f0f0bc52","subtype":"Chart","type":"Plot"},"ticker":{"id":"e0b92d2f-1874-47bb-9e61-cebef004d2e0","type":"BasicTicker"}},"id":"bea8fba2-1bbf-4a32-8d4e-daacaf68f344","type":"LinearAxis"},{"attributes":{"plot":{"id":"56eee1cb-e185-4e3d-bfe9-5b78f0f0bc52","subtype":"Chart","type":"Plot"}},"id":"2e325511-ec00-4758-98b7-83b187198bfe","type":"PreviewSaveTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"sp ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[3]</strong>&gt;</code></p>

# %%
p = Scatter(flowers, x='sepal_length', y='sepal_width', color='species', marker='species', legend='top_left')
show(p)
# Out:
#     <div class="plotdiv" id="a8946138-7a7b-44d1-b223-19a85d29cdb9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a8946138-7a7b-44d1-b223-19a85d29cdb9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a8946138-7a7b-44d1-b223-19a85d29cdb9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ac740ca9-0f16-47e3-af21-b0c64d6c7c3d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"},{"species":"versicolor"}],"species":["versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor","versicolor"],"x_values":[4.7,4.5,4.9,4.0,4.6,4.5,4.7,3.3,4.6,3.9,3.5,4.2,4.0,4.7,3.6,4.4,4.5,4.1,4.5,3.9,4.8,4.0,4.9,4.7,4.3,4.4,4.8,5.0,4.5,3.5,3.8,3.7,3.9,5.1,4.5,4.5,4.7,4.4,4.1,4.0,4.4,4.6,4.0,3.3,4.2,4.2,4.2,4.3,3.0,4.1],"y_values":[1.4,1.5,1.5,1.3,1.5,1.3,1.6,1.0,1.3,1.4,1.0,1.5,1.0,1.4,1.3,1.4,1.5,1.0,1.5,1.1,1.8,1.3,1.5,1.2,1.3,1.4,1.4,1.7,1.5,1.0,1.1,1.0,1.2,1.6,1.5,1.6,1.5,1.3,1.3,1.3,1.2,1.4,1.2,1.0,1.3,1.2,1.3,1.3,1.1,1.3]}},"id":"1b45ee61-a60c-4f32-9965-13ee51a0b274","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#407ee7"},"line_color":{"value":"#407ee7"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"70714995-5c8f-45d8-ba18-d5a4eaf3c2be","type":"Triangle"},{"attributes":{"dimension":1,"plot":{"id":"94390e86-71de-4820-a72b-d14a5001831d","subtype":"Chart","type":"Plot"},"ticker":{"id":"4aec2138-476e-47fe-bf46-4d82adafe69f","type":"BasicTicker"}},"id":"45311fcf-7878-48cd-b049-8789b1374471","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species":"virginica"},{"species" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %% [markdown]
# # Chart tools
#
# Charts, come with a set of default tools, as seen above, we're going to use a subset of these moving forward, feel free to play with the tools to see what interactions you get out of the box.

# %%
# Possible tools are: box_select, box_zoom, click, crosshair, 
# help, hover, lasso_select, pan, poly_select, previewsave, 
# reset, resize, save, tap, wheel_zoom, 
# xpan, xwheel_zoom, ypan or ywheel_zoom
TOOLS = 'pan,box_zoom,reset,'

# %% [markdown]
# # Box

# %%
from bokeh.charts import BoxPlot
p = BoxPlot(
    flowers, label='species', values='petal_width', tools='crosshair,box_zoom,box_select',
    xlabel='', ylabel='petal width, mm', title='Distribution of petal widths'
)
show(p)
# Out:
#     <div class="plotdiv" id="cbfaabfa-4cb7-4654-8b1f-298ac6e32d9b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cbfaabfa-4cb7-4654-8b1f-298ac6e32d9b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cbfaabfa-4cb7-4654-8b1f-298ac6e32d9b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b68b27a-6b53-402c-8a3b-3fdd9e36d6d1":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"},{"species":"setosa"}],"species":["setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa","setosa"],"x_values":[5.1,4.9,4.7,4.6,5.0,5.4,4.6,5.0,4.4,4.9,5.4,4.8,4.8,4.3,5.8,5.7,5.4,5.1,5.7,5.1,5.4,5.1,4.6,5.1,4.8,5.0,5.0,5.2,5.2,4.7,4.8,5.4,5.2,5.5,4.9,5.0,5.5,4.9,4.4,5.1,5.0,4.5,4.4,5.0,5.1,4.8,5.1,4.6,5.3,5.0],"y_values":[3.5,3.0,3.2,3.1,3.6,3.9,3.4,3.4,2.9,3.1,3.7,3.4,3.0,3.0,4.0,4.4,3.9,3.5,3.8,3.8,3.4,3.7,3.6,3.3,3.4,3.0,3.4,3.5,3.4,3.2,3.1,3.4,4.1,4.2,3.1,3.2,3.5,3.6,3.0,3.4,3.5,2.3,3.2,3.5,3.8,3.0,3.8,3.2,3.7,3.3]}},"id":"1b04a147-a542-40a8-9d42-b884c0aa22e1","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"294139f1-2baa-40b3-9a9f-b8ac74200875","subtype":"Chart","type":"Plot"},"ticker":{"id":"3d1ae4bd-c3d5-49fd-a30d-008613ed469f","type":"BasicTicker"}},"id":"0130539b-813d-4908-82be-3eef1651518a","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"dc1f4170-f9ad-4231-883c-1be773731780","type":"BoxAnnotation"},{"attributes":{},"id":"ef4f5daa-5ea6-4e05-98f7-75d65d4615c3","type":"CategoricalTicker"},{"attributes":{},"id":"976c4794-04d8-4bb2-bb2e-b31aad2d9ecb","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["y","fill_alpha","line_color","x","color","width","height","line_alpha"],"data":{"chart_index":[{"species":"versicolor"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[0.19999999999999996],"line_alpha":[1.0],"line_color":["black"],"species":["versicolor"],"width":[0.8],"x":["versicolor"],"y":[1.4]}},"id":"c437cafe-6083-413b-b477-33ed040eeb90","type":"ColumnDataSource"},{"attributes":{},"id":"d6a56757-cd18-4f06-b5ff-d83de0b84720","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"94390e86-71de-4820-a72b-d14a5001831d","subtype":"Chart","type":"Plot"}},"id":"940132b6-7674-40fc-a069-bb470fddb0b3","type":"WheelZoomTool"},{"attributes":{"below":[{"id":"2b32d998-2e16-4bb9-914f-9fffd2d837f4","type":"CategoricalAxis"}],"left":[{"id":"d6e62b7f-2e5c-480b-9262-d3593f293576","type":"LinearAxis"}],"legend":null,"renderers":[{"id":"dc1f4170-f9ad-4231-883c-1be773731780","type":"BoxAnnotation"},{"id":"19cbc7dc-fcb6-4e60-9fa4-9306e8775dbc","ty ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# # Bar

# %%
from bokeh.sampledata.autompg import autompg
autompg.head()
# Out:
#    mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0   18    8    307  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1   15    8    350  165    3693   11.5  70       1          buick skylark 320
# 2   18    8    318  150    3436   11.0  70       1         plymouth satellite
# 3   16    8    304  150    3433   12.0  70       1              amc rebel sst
# 4   17    8    302  140    3449   10.5  70       1                ford torino

# %%
from bokeh.charts import Bar
p = Bar(
    autompg, label='yr', values='mpg', agg='median', 
    group='origin', # Use the group feature
    title="Median MPG by YR, grouped by ORIGIN", legend='top_left', tools='crosshair'
)
show(p)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#         var all_models = [{"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "125c7487-1c03-4cfb-99fd-9dc83c13b943"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "b163d8cf-f1ba-44e3-8a00-3106f99e0a77"}, "id": "14ed2d9e-f4f3-45ee-8243-eb2c3471b8d6", "selection_glyph": null, "tags": []}, "id": "14ed2d9e-f4f3-45ee-8243-eb2c3471b8d6"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "0f75b73d-94d3-4d05-b0aa-2060ed73984c"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "8d4357ec-8af4-48a6-b384-8ca019d8925a"}, "id": "ddbc4f3a-49e9-4957-87df-49abc4888fef", "selection_glyph": null, "tags": []}, "id": "ddbc4f3a-49e9-4957-87df-49abc4888fef"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "f27e66c3-ab3a-470b-9e12-32c7bcc9482c", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "f27e66c3-ab3a-470b-9e12-32c7bcc9482c"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "4aa3829d-7048-45ba-989f-de3fe13301f4", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "4aa3829d-7048-45ba-989f-de3fe13301f4"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "009a4165-8f08-41c4-925c-c1e7f141f7cd"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "6927ded1-b74f-4f8c-bc60-fd9f479173cb"}, "id": "75f6918c-2eeb-42c9-8898-f392873e1fe0", "selection_glyph": null, "tags": []}, "id": "75f6918c-2eeb-42c9-8898-f392873e1fe0"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "a34c4137-08a9-4728-a860-0b2b3a93519b", "data": {"color": ["#5ab738"], "x": ["78:0.25"], "width": [0.2], "fill_alpha": [0.8], "y": [10.475000000000001], "height": [20.950000000000003]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "a34c4137-08a9-4728-a860-0b2b3a93519b"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "125c7487-1c03-4cfb-99fd-9dc83c13b943", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "125c7487-1c03-4cfb-99fd-9dc83c13b943"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "009a4165-8f08-41c4-925c-c1e7f141f7cd", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "009a4165-8f08-41c4-925c-c1e7f141f7cd"}, {"type": "ToolEvents", "attributes": {"geometries": [], "doc": null, "id": "a83b60c1-bc73-4dec-be31-df405d76a437", "tags": []}, "id": "a83b60c1-bc73-4dec-be31-df405d76a437"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "381c096c-9560-4ee1-baed-dd0425fd5fc3", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "381c096c-9560-4ee1-baed-dd0425fd5fc3"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "f139eb74-8b31-4db3-a20c-2a6a5ab2db3d"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "a34c4137-08a9-4728-a860-0b2b3a93519b"}, "id": "12081484-ca6a-4155-a42c-ab438c617e7d", "selection_glyph": null, "tags": []}, "id": "12081484-ca6a-4155-a42c-ab438c617e7d ...

# %%
from bokeh.charts import Bar
p = Bar(
    autompg, label='yr', values='mpg', agg='median', 
    stack='origin', # Use the stack feature
    title="Median MPG by YR, stacked by ORIGIN", legend='top_left', tools='crosshair'
)
show(p)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#         var all_models = [{"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "c6064895-dbad-4e85-a18e-c2793a3b6aef", "data": {"color": ["#f22c40"], "x": ["74"], "width": [0.8], "fill_alpha": [0.8], "y": [8.0], "height": [16.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "c6064895-dbad-4e85-a18e-c2793a3b6aef"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "d8b41487-a7b3-49be-8004-d9dbd98c77c2"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "88164dc4-8fb7-4809-a8d6-434fb4ea1f87"}, "id": "d9be5b82-2e61-444b-aa3c-a391e781ecd1", "selection_glyph": null, "tags": []}, "id": "d9be5b82-2e61-444b-aa3c-a391e781ecd1"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "2d177a8f-c921-4119-8211-f42c3481e281", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "2d177a8f-c921-4119-8211-f42c3481e281"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "ba45a62e-db05-4e63-98e3-0378b2c8ad66", "data": {"color": ["#407ee7"], "x": ["75"], "width": [0.8], "fill_alpha": [0.8], "y": [54.75], "height": [26.5]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "ba45a62e-db05-4e63-98e3-0378b2c8ad66"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "fae4e13a-4da2-4590-bd56-12a5a784566e"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "efb16ed3-757f-4630-a224-4385e68f01be"}, "id": "234ac8a9-6fe6-4b62-a0fe-2a2824f55708", "selection_glyph": null, "tags": []}, "id": "234ac8a9-6fe6-4b62-a0fe-2a2824f55708"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "d29c2f1f-2934-4082-b55e-8c13d7f9001c", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "d29c2f1f-2934-4082-b55e-8c13d7f9001c"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "177998e0-6f13-4bd4-a459-1555624d32ef", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "177998e0-6f13-4bd4-a459-1555624d32ef"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "e52d1e01-55ee-4894-a3e4-a4349e6e0d2d", "data": {"color": ["#407ee7"], "x": ["77"], "width": [0.8], "fill_alpha": [0.8], "y": [61.75], "height": [28.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "e52d1e01-55ee-4894-a3e4-a4349e6e0d2d"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "fb2a4b43-1491-4ed2-a282-addd886f4894", "data": {"color": ["#f22c40"], "x": ["72"], "width": [0.8], "fill_alpha": [0.8], "y": [7.0], "height": [14.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "fb2a4b43-1491-4ed2-a282-addd886f4894"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "8d0ddd5b-c477-444b-a2bd-924994b8c178"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "78b3f730-8426-49c0-b3f3-30ba1472396d"}, "id": "43d0e1a2-78f5-4358-8887-43e42a62267a",  ...

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import numpy as np

# build some distributions
mu, sigma = 0, 0.5
normal = pd.DataFrame({'value': np.random.normal(mu, sigma, 1000), 'type': 'normal'})
lognormal = pd.DataFrame({'value': np.random.lognormal(mu, sigma, 1000), 'type': 'lognormal'})

# create a pandas data frame
df = pd.concat([normal, lognormal])
df[995:1005]
# Out:
#           type     value
# 995     normal  1.035638
# 996     normal -0.758503
# 997     normal  0.805719
# 998     normal -1.253977
# 999     normal  0.045442
# 0    lognormal  0.633237
# 1    lognormal  0.994970
# 2    lognormal  2.162434
# 3    lognormal  0.760505
# 4    lognormal  1.024579

# %%
from bokeh.charts import Histogram
hist = Histogram(df, values='value', color='type', bins=50, legend=True)
show(hist)
# Out:
# <script type="text/javascript">
#         Bokeh.$(function() {
#         var all_models = [{"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "05378d1b-e7a0-4a81-8db5-c33f004aee21", "data": {"color": ["#5ab738"], "x": [0.7150000000000001], "width": [0.07000000000000006], "fill_alpha": [0.6], "y": [7.5], "height": [15.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "05378d1b-e7a0-4a81-8db5-c33f004aee21"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "aa015768-ede0-4895-880e-d78ac749cd73", "data": {"color": ["#f22c40"], "x": [3.265], "width": [0.09], "fill_alpha": [0.6], "y": [1.5], "height": [3.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "aa015768-ede0-4895-880e-d78ac749cd73"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "e7b97939-b104-4eb1-8bbd-6ba3b93f7823"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "48b72d07-257b-4734-a02d-06721dd7e630"}, "id": "128ca5aa-a6e6-450a-bd24-a9bc45910714", "selection_glyph": null, "tags": []}, "id": "128ca5aa-a6e6-450a-bd24-a9bc45910714"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "1d753071-23fb-4f99-91b0-d119cce3357c", "data": {"color": ["#f22c40"], "x": [4.255], "width": [0.09], "fill_alpha": [0.6], "y": [0.0], "height": [0.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "1d753071-23fb-4f99-91b0-d119cce3357c"}, {"type": "Rect", "attributes": {"x": {"field": "x"}, "y": {"field": "y"}, "fill_color": {"field": "color"}, "id": "830d27e0-2c2d-4605-8044-db9b46b9382b", "width": {"units": "data", "field": "width"}, "fill_alpha": {"field": "fill_alpha"}, "doc": null, "tags": [], "height": {"units": "data", "field": "height"}}, "id": "830d27e0-2c2d-4605-8044-db9b46b9382b"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "624788ce-c00f-4f47-9dc9-f6551400c7e8"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "0cd9483e-9db1-4405-bf8a-26298720a0eb"}, "id": "60800fb2-508f-4708-a2e6-3f9f0963b2af", "selection_glyph": null, "tags": []}, "id": "60800fb2-508f-4708-a2e6-3f9f0963b2af"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "fe5a6b9b-a0ef-4ba1-b61c-452ff95a34d6", "data": {"color": ["#5ab738"], "x": [1.685], "width": [0.07000000000000006], "fill_alpha": [0.6], "y": [0.0], "height": [0.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "fe5a6b9b-a0ef-4ba1-b61c-452ff95a34d6"}, {"type": "ColumnDataSource", "attributes": {"column_names": ["color", "x", "width", "fill_alpha", "y", "height"], "callback": null, "doc": null, "tags": [], "id": "1d1e80ef-0d39-4d92-a51e-c489a69edad0", "data": {"color": ["#f22c40"], "x": [3.175], "width": [0.09], "fill_alpha": [0.6], "y": [0.5], "height": [1.0]}, "selected": {"0d": {"indices": [], "flag": false}, "2d": {"indices": []}, "1d": {"indices": []}}}, "id": "1d1e80ef-0d39-4d92-a51e-c489a69edad0"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "2428bdaf-f14c-4c72-8ab9-1d1d2e91aa6a"}, "nonselection_glyph": null, "doc": null, "data_source": {"type": "ColumnDataSource", "id": "aa015768-ede0-4895-880e-d78ac749cd73"}, "id": "92013962-b59b-4872-90dc-90bf485d016a", "selection_glyph": null, "tags": []}, "id": "92013962-b59b-4872-90dc-90bf485d016a"}, {"type": "GlyphRenderer", "attributes": {"glyph": {"type": "Rect", "id": "3ad79db2-4396-4f6e-a612-dbc269f568b1"}, "nonselection_g ...

# %% [markdown]
# # Exercises

# %%
from bokeh.sampledata.us_marriages_divorces import data as marriages_divorces
marriages_divorces.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867     357000     10000    36970000                 9.7
# 1  1868     345000     10000    37885000                 9.1
# 2  1869     348000     11000    38870000                 9.0
# 3  1870     352000     11000    39905000                 8.8
# 4  1871     359000     12000    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %% [markdown]
# Make a bar chart from the above data frame that looks like
#
# <img src="assets/images/charts_line.png" style="width: 500px; float: left">

# %%
from bokeh.charts import Line
line = Line?
show(line)

# %% [markdown]
# ### Try varying the dash
#
# https://github.com/bokeh/bokeh/blob/master/examples/charts/file/line_single.py
#
# ---

# %%
from utils import get_medal_data
medals = get_medal_data()
medals.head()
# Out:
#    count   medal       name country
# 0      1  bronze  Australia     AUS
# 1      2  silver  Australia     AUS
# 2      0    gold  Australia     AUS
# 3      1  bronze    Austria     AUT
# 4      6  silver    Austria     AUT

# %% [markdown]
# ### Make a bar chart from the above data frame that looks like
#
# <img src="assets/images/charts_medal_stacked.png" style="width: 350px; float: left">

# %%
bar = Bar(...)
show(bar)

# %% [markdown]
# ### Try tweaking the display and styling:
#
# <img src="assets/images/charts_medal_stacked_colored.png" style="width: 350px; float: left">

# %%
bar = Bar(...)
show(bar)

# %% [markdown]
# ## Advanced

# %% [markdown]
# ### Investigate blend
#
# https://github.com/bokeh/bokeh/blob/master/examples/charts/file/iris_blend.py

# %% [markdown]
# ### Investigate attribute specification
#
# https://github.com/bokeh/bokeh/blob/master/examples/howto/charts/deep_dive-attributes.ipynb

# %% [markdown]
# ---
#
# # Further reading
#
# * User guide: http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html
# * Reference guide: http://bokeh.pydata.org/en/latest/docs/reference/charts.html
# * Examples:  https://github.com/bokeh/bokeh/blob/master/examples/charts/
#
# * Area
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/area.py
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/palettes.py
# * Heatmap
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/heatmap.py
# * Donut
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/donut.py
# * Dots
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/dots.py
# * Horizon
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/horizon.py
#  * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/horizon_folds.py
# * Step
#   * https://github.com/bokeh/bokeh/blob/master/examples/charts/file/steps.py
